# %%
# Demo: Read YouTube Bronze Data with PySpark
from pyspark.sql import SparkSession
from pyspark.sql import functions as F
from pyspark.sql.types import StructType, StructField, StringType, LongType

spark = (
    SparkSession.builder
    .master("local[*]")
    .appName("youtube-bronze-demo")
    .getOrCreate()
)
print(f"Spark version: {spark.version}")
spark
# Out:
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# Spark version: 3.5.4-amzn-0
#             <div>
#                 <p><b>SparkSession - hive</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="None">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.5.4-amzn-0</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[*]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>youtube-bronze-demo</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %%
import glob as pyglob

BRONZE_PATH = "/home/hadoop/workspace/data/bronze/metadata/source=channel"

files = pyglob.glob(f"{BRONZE_PATH}/dt=*/*/_compacted.jsonl")
lines = []
for f in files:
    with open(f) as fh:
        lines.extend(line.strip() for line in fh if line.strip())

raw_df = spark.read.json(spark.sparkContext.parallelize(lines))

# %%
# Flatten into a Silver-like analytical view
silver_df = (
    raw_df
    .select(
        F.col("id").alias("video_id"),
        F.col("snippet.channelId").alias("channel_id"),
        F.col("snippet.channelTitle").alias("channel_name"),
        F.col("snippet.title").alias("title"),
        F.col("snippet.publishedAt").alias("published_at"),
        F.col("statistics.viewCount").cast(LongType()).alias("view_count"),
        F.col("statistics.likeCount").cast(LongType()).alias("like_count"),
        F.col("statistics.commentCount").cast(LongType()).alias("comment_count"),
        F.col("contentDetails.duration").alias("duration"),
    )
    .withColumn("like_view_ratio", F.round(F.col("like_count") / F.col("view_count"), 4))
)

silver_df.show(truncate=50)
# Out:
# +-----------+------------------------+---------------------+--------------------------------------------------+--------------------+----------+----------+-------------+----------+---------------+
# |   video_id|              channel_id|         channel_name|                                             title|        published_at|view_count|like_count|comment_count|  duration|like_view_ratio|
# +-----------+------------------------+---------------------+--------------------------------------------------+--------------------+----------+----------+-------------+----------+---------------+
# |7ysrM5BMe6Q|UC8butISFwT-Wl7EV0hUK0BQ|     freeCodeCamp.org|Don't get so wrapped up in the details that you...|2026-02-12T12:52:59Z|      2542|        20|            1|     PT58S|         0.0079|
# |KUbbb0T1YZ8|UC8butISFwT-Wl7EV0hUK0BQ|     freeCodeCamp.org| Have you ever wondered where Python got its name?|2026-02-11T13:29:30Z|      3660|        18|            1|     PT12S|         0.0049|
# |UJjKVceWmdM|UC8butISFwT-Wl7EV0hUK0BQ|     freeCodeCamp.org|Knowing how to ask the right question is a valu...|2026-02-13T13:18:29Z|      4986|        40|            0|     PT39S|          0.008|
# |cjam-BWAaL8|UC8butISFwT-Wl7EV0hUK0BQ|     freeCodeCamp.org|Why maintaining a codebase is so damn hard – wi...|2026-02-13T11:01:10Z|      5744|       189|            2| PT1H23M4S|         0.0329|
# |gmuTjeQUbTM|UC8butISFwT-Wl7EV0hUK0BQ|     freeCodeCamp.org|Harvard CS50 (2026) – Full Computer Science Uni...|2026-02-05T13:45:14Z|    305970|     15093|          639|P1DT29M14S|         0.0493|
# |l57xKN6OBhY|UC8butISFwT-Wl7EV0hUK0BQ|     freeCodeCamp.org|Kubernetes Course – Certified Kubernetes Admini...|2026-02-10T11:01:25Z|     19211|       915|           25| PT2H6M25S|         0.0476|
# |lEcULR30-GM|UC8butISFwT-Wl7EV0hUK0BQ|     freeCodeCamp.org|Master Full-Stack Docker & CI/CD – Build a Prod...|2026-02-12T14:02:47Z|     26697|      1536|           24|PT3H58M43S|         0.0575|
# |n1sfrc-RjyM|UC8butISFwT-Wl7EV0hUK0BQ|     freeCodeCamp.org|OpenClaw Full Tutorial for Beginners – How to S...|2026-02-04T11:01:21Z|    199268|      5024|          324|  PT54M45S|         0.0252|
# |ug8W0sFiVJo|UC8butISFwT-Wl7EV0hUK0BQ|     freeCodeCamp.org|Hands-On Cybersecurity and Ethical Hacking – Fu...|2026-02-11T14:37:23Z|     54439|      3839|          132|PT3H35M45S|         0.0705|
# |46dX6AAcx7I|UC_x5XG1OV2P6uZZ5FSM9Ttw|Google for Developers|                          Build with AI 2025 Recap|2026-01-14T00:00:05Z|      2688|        90|            9|    PT1M1S|         0.0335|
# |9xlYYfQhU8U|UC_x5XG1OV2P6uZZ5FSM9Ttw|Google for Developers|           Improve unit testing with test doubles!|2026-02-13T17:11:44Z|      2428|        79|            6|   PT2M18S|         0.0325|
# |dq6mUPvL4dI|UC_x5XG1OV2P6uZZ5FSM9Ttw|Google for Developers|From the news desk 📰:  What is Universal Comme...|2026-02-11T20:00:29Z|      4334|       116|            6|   PT1M17S|         0.0268|
# |iswLOoreuyM|UC_x5XG1OV2P6uZZ5FSM9Ttw|Google for Developers|Google AI Studio's new homepage and omnibar for...|2026-02-12T00:02:27Z|      3454|       110|            6|     PT41S|         0.0318|
# |mphShv2MJcY|UC_x5XG1OV2P6uZZ5FSM9Ttw|Google for Developers|Google AI Studio: Account setup, rate limits & ...|2026-02-14T00:01:02Z|      1161|        70|            7|   PT1M47S|         0.0603|
# |MYfC38H0VWs|UCVHFbqXqoYvEWM1Ddxl0QDg|   Android Developers|         Audit and fix UI issues in Android Studio|2026-02-11T22:08:23Z|      2209|        63|            1|     PT38S|         0.0285|
# |Re0E4YXpFOc|UCVHFbqXqoYvEWM1Ddxl0QDg|   Android Developers|              Debugging R8 in Android Studio Otter|2026-02-12T19:48:44Z|      1166|        42|            0|     PT38S|          0.036|
# |S0Lv0rtyidg|UCVHFbqXqoYvEWM1Ddxl0QDg|   Android Developers|               3 Google Play tools every Dev needs|2026-02-11T22:49:37Z|      2146|        84|            2|      PT1M|         0.0391|
# |eJnC2Zfgopw|UCVHFbqXqoYvEWM1Ddxl0QDg|   Android Developers|What is android studio's "Fix UI" AI feature an...|2026-02-11T16:01:05Z|      4613|       151|            5|     PT44S|         0.0327|
# +-----------+------------------------+---------------------+--------------------------------------------------+--------------------+----------+----------+-------------+----------+---------------+

# %%
# Top videos by engagement (like/view ratio)
print("=== Top 10 Videos by Engagement ===")
(
    silver_df
    .orderBy(F.col("like_view_ratio").desc())
    .select("channel_name", "title", "view_count", "like_count", "like_view_ratio")
    .show(10, truncate=60)
)

# %%
# Aggregate stats per channel
print("=== Channel Summary ===")
(
    silver_df
    .groupBy("channel_name")
    .agg(
        F.count("*").alias("video_count"),
        F.sum("view_count").alias("total_views"),
        F.sum("like_count").alias("total_likes"),
        F.round(F.avg("like_view_ratio"), 4).alias("avg_engagement"),
    )
    .orderBy(F.col("total_views").desc())
    .show(truncate=False)
)

# %%
spark.stop()
